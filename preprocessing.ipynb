# %% [markdown]
# ### 1. Clipping Video Per 3 Detik

# %%
import os
print("Current working directory:", os.getcwd())
import cv2

def split_and_filter(input_path, output_folder, label, clip_duration=3):
    os.makedirs(output_folder, exist_ok=True)

    cap = cv2.VideoCapture(input_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frames_per_clip = int(fps * clip_duration)

    clip_index = 1
    frame_index = 0
    out = None

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # Setiap mulai 1 clip baru
        if frame_index % frames_per_clip == 0:
            # Tutup writer sebelumnya
            if out is not None:
                out.release()

            # Tentukan apakah clip ini disimpan atau tidak
            save_clip = True

            if label == "cheating":
                # Clip ganjil = disimpan
                # Clip genap  = normal = dibuang
                if clip_index % 2 == 0:
                    save_clip = False

            if save_clip:
                clip_name = f"{os.path.splitext(os.path.basename(input_path))[0]}_clip{clip_index:03d}.mp4"
                output_path = os.path.join(output_folder, clip_name)

                fourcc = cv2.VideoWriter_fourcc(*"mp4v")
                out = cv2.VideoWriter(output_path, fourcc, fps, (frame.shape[1], frame.shape[0]))
            else:
                out = None

            clip_index += 1

        # Kalau clip ini disimpan, tulis frame
        if out is not None:
            out.write(frame)

        frame_index += 1

    if out is not None:
        out.release()
    cap.release()



def process_dataset(base_path="dataset", clip_duration=3):
    for label in os.listdir(base_path):
        label_path = os.path.join(base_path, label)
        if not os.path.isdir(label_path):
            continue

        # Cek apakah langsung ada file video di label_path
        video_files = [f for f in os.listdir(label_path) if f.endswith((".mp4", ".avi", ".mov"))]
        if video_files:
            output_path = os.path.join(base_path, "..", "dataset_clips", label)
            output_path = os.path.abspath(output_path)
            os.makedirs(output_path, exist_ok=True)
            for filename in video_files:
                input_path = os.path.join(label_path, filename)
                split_and_filter(input_path, output_path, label, clip_duration)
                print(f"✔ Proses selesai: {input_path}")
        else:
            # Jika ada subfolder (angle)
            for angle in os.listdir(label_path):
                angle_path = os.path.join(label_path, angle)
                if not os.path.isdir(angle_path):
                    continue
                output_path = os.path.join(base_path, "..", "dataset_clips", label, angle)
                output_path = os.path.abspath(output_path)
                os.makedirs(output_path, exist_ok=True)
                for filename in os.listdir(angle_path):
                    if filename.endswith((".mp4", ".avi", ".mov")):
                        input_path = os.path.join(angle_path, filename)
                        split_and_filter(input_path, output_path, label, clip_duration)
                        print(f"✔ Proses selesai: {input_path}")


# Jalankan
process_dataset("/run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset", clip_duration=3)
# Out:
# Current working directory: /home/han/Documents/Kuliah/S5/Comvis/Projek
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c100.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c101.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c102.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c103.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c104.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c105.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c106.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c107.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c108.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c109.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c110.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c111.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c112.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c113.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c114.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c115.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c116.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c117.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c118.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c119.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c120.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c121.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c122.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c123.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c124.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c125.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c126.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c127.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_2.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_3.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_3_menoleh_kanan_kiri_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_3_menoleh_kanan_kiri_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_4.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_5.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_6.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_6_melihat_hp_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_6_melihat_hp_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_7.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_7_melihat_kertas_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_7_melihat_kertas_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_8.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_8_ngasih_kertas_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_8_ngasih_kertas_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_9.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_13.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_14.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_15.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_15_gerak_tangan_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_15_gerak_tangan_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_16.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_16_melihat_belakang_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_16_melihat_belakang_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_17_dorong_kertas_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_17_dorong_kertas_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_18_melihat_tangan_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_18_melihat_tangan_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_19_combo_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c38.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c39.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c40.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c41.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c42.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c43.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c44.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c45.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c46.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c47.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c48.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c49.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c50.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c51.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c52.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c53.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c54.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c55.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c56.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c57.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c59.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c60.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c61.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c62.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c63.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c64.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c65.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c66.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c67.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c68.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c69.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c70.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c71.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c72.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c73.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c74.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c75.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c76.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c77.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c78.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c17.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c37.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c58.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c79.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_12.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_19_combo_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c80.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c81.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c82.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c83.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c84.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c85.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c86.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c87.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c88.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c89.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c90.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c91.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c92.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c93.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c94.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c95.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c96.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c97.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c98.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c99.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_1.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_10.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_11.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_11_gestur_tangan_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/cheating_11_gestur_tangan_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c18.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c19.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c20.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c21.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c22.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c23.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c24.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c25.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c26.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c27.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c28.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c29.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c30.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c31.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c32.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c33.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c34.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c35.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/cheating/c36.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc1..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc10..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc100.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc101.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc102.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc103.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc104.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc105.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc106.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc107.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc108.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc109.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc11..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc110.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc111.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc112.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc113.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc114.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc115.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_11_membaca_ke_depan_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_12_mengusap_wajah_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_12_mengusap_wajah_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_13_betulkan_posisi_kertas_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_13_betulkan_posisi_kertas_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_14_cek_jam_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_14_cek_jam_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_15_betulkan_baju_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_15_betulkan_baju_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_16_mencari_sesuatu_dimeja_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_16_mencari_sesuatu_dimeja_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_17_mengusap_meja_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_18_duduk_diam_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_18_duduk_diam_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_1_menulis_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_1_menulis_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_2_membaca_soal_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_2_membaca_soal_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_3_melihat_papan_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_3_melihat_papan_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_4_mengatur_alat_tulis_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_4_mengatur_alat_tulis_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_5_garuk_kepala_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_5_garuk_kepala_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_6_peregangan_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_6_peregangan_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_7_menguap_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_7_menguap_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_8_minum_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_8_minum_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_9_mengambil_barang_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_9_mengambil_barang_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nv127.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc28.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc29.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc3..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc30.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc31.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc32.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc33.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc34.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc35.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc36.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc37.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc38.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc39.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc4..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc40.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc41.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc42.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc43.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc44.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc46.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc47.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc48.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc49.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc5..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc50.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc51.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc52.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc53.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc54.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc55.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc56.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc57.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc58.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc59.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc6..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc60.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc61.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc62.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc116.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc135.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc27.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc45.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc63.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc81.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_11_membaca_ke_depan_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_17_mengusap_meja_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc64.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc65.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc66.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc67.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc68.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc69.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc7..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc70.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc71.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc72.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc73.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc74.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc75.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc76.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc77.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc78.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc79.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc8..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc80.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc82.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc83.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc84.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc85.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc86.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc87.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc88.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc89.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc9..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc90.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc91.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc92.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc93.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc94.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc95.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc96.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc97.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc98.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc99.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_10_betulkan_posisi_duduk_depan.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/not_cheating_10_betulkan_posisi_duduk_fixed_samping.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc117.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc118.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc119.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc12..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc120.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc121.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc122.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc123.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc124.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc125.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc126.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc128.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc129.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc13..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc130.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc131.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc132.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc133.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc134.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc136.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc137.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc138.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc139.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc14..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc140.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc141.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc142.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc143.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc144.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc145.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc146.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc147.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc148.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc149.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc15..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc150.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc16..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc17..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc18.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc19.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc2..mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc20.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc21.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc22.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc23.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc24.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc25.mp4
# ✔ Proses selesai: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/RAW Dataset/not_cheating/nc26.mp4

# %% [markdown]
# ### 2. Membagi Dataset ke Folder train, val, test

# %%
import os
import shutil
import random
from pathlib import Path

# ==== KONFIGURASI ====
SRC_DIR = Path("/run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/Preprocessing/dataset_clips")
OUT_DIR = Path("/run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/Preprocessing/dataset_clips_split")

SPLIT = {
    "train": 0.7,
    "val": 0.15,
    "test": 0.15
}

VIDEO_EXT = [".mp4", ".avi", ".mov", ".mkv"]

# ==== Buat folder output ====
for split in SPLIT:
    (OUT_DIR / split / "cheating").mkdir(parents=True, exist_ok=True)
    (OUT_DIR / split / "not_cheating").mkdir(parents=True, exist_ok=True)

def list_all_clips(class_name):
    """Mengambil semua clip dari folder Cheating/Not Cheating termasuk subfoldernya."""
    clips = []
    class_path = SRC_DIR / class_name

    for root, _, files in os.walk(class_path):
        for f in files:
            if any(f.lower().endswith(ext) for ext in VIDEO_EXT):
                clips.append(Path(root) / f)

    return clips

# ==== Ambil semua clip ====
cheat_clips = list_all_clips("cheating")
not_cheat_clips = list_all_clips("not_cheating")

print("[INFO] Total Cheating:", len(cheat_clips))
print("[INFO] Total Not Cheating:", len(not_cheat_clips))

def split_dataset(files):
    """Split file list ke train/val/test."""
    random.shuffle(files)
    n = len(files)
    t = int(SPLIT["train"] * n)
    v = int(SPLIT["val"] * n)

    return {
        "train": files[:t],
        "val": files[t:t+v],
        "test": files[t+v:]
    }

cheat_split = split_dataset(cheat_clips)
not_cheat_split = split_dataset(not_cheat_clips)

# ==== COPY DENGAN NAMA BARU ====
def copy_with_new_name(files, split, class_name):
    for idx, src in enumerate(files):
        new_name = f"{class_name.lower().replace(' ', '_')}_{idx:05d}.mp4"
        dst = OUT_DIR / split / class_name / new_name
        shutil.copy2(src, dst)

# Cheating
for split in SPLIT:
    copy_with_new_name(cheat_split[split], split, "cheating")

# Not Cheating
for split in SPLIT:
    copy_with_new_name(not_cheat_split[split], split, "not_cheating")
print("=== Dataset Berhasil Dibuat! ===")
print("Lokasi:", OUT_DIR)
# Out:
# [INFO] Total Cheating: 741
# [INFO] Total Not Cheating: 1850
# === Dataset Berhasil Dibuat! ===
# Lokasi: /run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/Preprocessing/dataset_clips_split

# %% [markdown]
# ### 3. Crop Video Menggunakan YOLO

# %%
import cv2
import os
import numpy as np
from ultralytics import YOLO
from tqdm import tqdm

# --- KONFIGURASI UTAMA ---
INPUT_ROOT = "/run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/Preprocessing/dataset_clips_split"          # Folder Input
OUTPUT_ROOT = "/run/media/han/HDD RAIHAN/Real Dataset Cheating Comvis/Preprocessing/dataset_clips_split_ready" # Folder Output
TARGET_SIZE = 112                             # Ukuran input R3D

# --- KONFIGURASI SMOOTHING ---
SMOOTHING_FACTOR = 0.7 

# Load YOLO
model = YOLO("yolov8n.pt") 

# --- FUNGSI 1: CROP & PAD (Agar Gambar Tidak Gepeng) ---
def crop_padded_square(frame, box, target_size):
    h, w, _ = frame.shape
    x1, y1, x2, y2 = map(int, box)
    
    # Safety Check
    x1 = max(0, x1); y1 = max(0, y1)
    x2 = min(w, x2); y2 = min(h, y2)
    
    crop = frame[y1:y2, x1:x2]
    
    if crop.size == 0:
        return np.zeros((target_size, target_size, 3), dtype=np.uint8)

    # Padding to Square
    ch, cw, _ = crop.shape
    delta_w = max(ch - cw, 0)
    delta_h = max(cw - ch, 0)
    top, bottom = delta_h // 2, delta_h - (delta_h // 2)
    left, right = delta_w // 2, delta_w - (delta_w // 2)

    color = [0, 0, 0]
    new_im = cv2.copyMakeBorder(crop, top, bottom, left, right, cv2.BORDER_CONSTANT, value=color)
    final_im = cv2.resize(new_im, (target_size, target_size))
    return final_im

# --- FUNGSI 2: PROSES VIDEO DENGAN SMOOTHING ---
def process_video_smoothed(input_path, output_dir, filename_base):
    cap = cv2.VideoCapture(input_path)
    fps = int(cap.get(cv2.CAP_PROP_FPS))
    if fps == 0: fps = 30
    
    writers = {}
    previous_boxes = {} 

    while True:
        ret, frame = cap.read()
        if not ret: break
        
        # Tracking YOLO
        results = model.track(frame, classes=[0], persist=True, verbose=False, tracker="bytetrack.yaml")
        
        if results[0].boxes.id is not None:
            boxes = results[0].boxes.xyxy.cpu().numpy()
            track_ids = results[0].boxes.id.cpu().numpy().astype(int)
            
            for box, track_id in zip(boxes, track_ids):
                current_box = box 
                
                # EMA Smoothing
                if track_id in previous_boxes:
                    prev_box = previous_boxes[track_id]
                    smoothed_box = (SMOOTHING_FACTOR * current_box) + ((1 - SMOOTHING_FACTOR) * prev_box)
                else:
                    smoothed_box = current_box
                
                previous_boxes[track_id] = smoothed_box
                final_box_int = smoothed_box.astype(int)

                # Writer Setup
                if track_id not in writers:
                    out_name = f"{filename_base}_id{track_id}.mp4"
                    out_path = os.path.join(output_dir, out_name)
                    fourcc = cv2.VideoWriter_fourcc(*'mp4v')
                    writers[track_id] = cv2.VideoWriter(out_path, fourcc, fps, (TARGET_SIZE, TARGET_SIZE))
                
                # Crop & Write
                final_frame = crop_padded_square(frame, final_box_int, TARGET_SIZE)
                writers[track_id].write(final_frame)

    cap.release()
    for w in writers.values():
        w.release()

# --- MAIN LOOP ---
print("🚀 Mulai Memproses Dataset (Mode SMOOTHING)...")

# PERUBAHAN DI SINI: Menambahkan "test" ke dalam list
TARGET_FOLDERS = ["train", "val", "test"]

for split in TARGET_FOLDERS:
    for cls in ["cheating", "not_cheating"]:
        
        input_dir = os.path.join(INPUT_ROOT, split, cls)
        output_dir = os.path.join(OUTPUT_ROOT, split, cls)
        
        # Cek apakah folder input ada
        if not os.path.exists(input_dir): 
            # Jangan print error berlebihan, cukup skip silent atau info kecil
            # print(f"Info: Folder {split}/{cls} tidak ditemukan, skip.")
            continue
            
        os.makedirs(output_dir, exist_ok=True)
        videos = [f for f in os.listdir(input_dir) if f.endswith(".mp4")]
        
        if len(videos) > 0:
            print(f"\n📂 Processing {split}/{cls} ({len(videos)} videos)...")
            
            for vid_name in tqdm(videos):
                input_path = os.path.join(input_dir, vid_name)
                filename_base = os.path.splitext(vid_name)[0]
                process_video_smoothed(input_path, output_dir, filename_base)

print("\n✅ Selesai! Semua folder (Train, Val, Test) telah diproses.")
# Out:
# 🚀 Mulai Memproses Dataset (Mode SMOOTHING)...
#
# 📂 Processing train/cheating (518 videos)...
# 100%|██████████| 518/518 [05:21<00:00,  1.61it/s]
# 📂 Processing train/not_cheating (1295 videos)...
# 100%|██████████| 1295/1295 [13:09<00:00,  1.64it/s]
# 📂 Processing val/cheating (111 videos)...
# 100%|██████████| 111/111 [01:09<00:00,  1.60it/s]
# 📂 Processing val/not_cheating (277 videos)...
# 100%|██████████| 277/277 [02:53<00:00,  1.60it/s]
# 📂 Processing test/cheating (112 videos)...
# 100%|██████████| 112/112 [01:10<00:00,  1.59it/s]
# 📂 Processing test/not_cheating (278 videos)...
# 100%|██████████| 278/278 [02:52<00:00,  1.62it/s]
# ✅ Selesai! Semua folder (Train, Val, Test) telah diproses.
